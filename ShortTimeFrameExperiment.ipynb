# %%
import math
import numpy as np

import mido
import librosa
import librosa.display

import IPython.display as ipd
import matplotlib.pyplot as plt
from torch import optim
import torch.utils.data as utils

import torch.nn.functional as F
from torch import nn
import torch

windowSize=50
n_fft=2048
hopLength=256

# %%
y, sr = librosa.load('4Beats2MelLong4.wav')

# %%
D = np.array(librosa.stft(y,n_fft=n_fft,hop_length=hopLength))
del y

# %%
midiArray=[]
HopSize=hopLength/sr
timeTracker=0.0
totalTimeTracker=0.0
MemoryArray=np.zeros(128)
lasttime=0;
bpm=60
for msg in mido.MidiFile('4Beats2MelLong4.mid'):
    if not msg.is_meta:
        totalTimeTracker+=msg.time
        nextEventTime=lasttime+msg.time
        while nextEventTime> timeTracker + HopSize:
            MemoryArray[127]=((timeTracker%4) * (bpm/60.0))/4.0
            midiArray.append(MemoryArray.copy())
            timeTracker += HopSize;
        if msg.type=='note_on':
            MemoryArray[msg.note]+=1.0;
        elif msg.type=='note_off':
            MemoryArray[msg.note]-=1.0;
        if(timeTracker+msg.time >= timeTracker + HopSize):
            MemoryArray[127]=((timeTracker%4) * (bpm/60.0))/4.0
            midiArray.append(MemoryArray.copy())
            timeTracker += HopSize
        lasttime += msg.time
    else:
        if(msg.type == 'set_tempo'):
            bpm=60000000/msg.tempo
midiArray=np.array(midiArray)

# %%
minLength = min(midiArray.shape[0],D.T.shape[0])
midiArray=midiArray[:minLength];
D_data=np.array([np.append(np.float32(elem.real), np.float32(elem.imag)) for elem in D.T[:midiArray.shape[0]]])

# %%
print(D.T.shape,midiArray.shape)
print(midiArray.shape,D_data.shape)
print(midiArray.dtype,D_data.dtype)
# Out:
# (141258, 1025) (141145, 128)
# (141145, 128) (141145, 2050)
# float64 float32

# %%
outPutMidiArray=[]
for i in range(midiArray.shape[0]):
    temp=[]
    for j in range(windowSize):
        val = int(j-(windowSize)) #int(j-(np.floor(windowSize/2))) #int(j-(windowSize)) 
        val = i+val
        if(val<0 or val+1>midiArray.shape[0]):
             temp.append(np.zeros(midiArray.shape[1]))
        else:
            temp.append(midiArray[val])
    outPutMidiArray.append(temp)
outPutMidiArray=np.array(outPutMidiArray)
del midiArray

# %%
plt.imshow(outPutMidiArray[550].T)

# %%
## Solution

class Network(nn.Module):
    def __init__(self):
        super().__init__()
        # Defining the layers, 128, 64, 10 units each
        self.fc1 = nn.Linear(128*windowSize, 128*2)
        self.fc2 = nn.Linear(128*2, 10000)
        self.fc4 = nn.Linear(10000, n_fft+2)

    def forward(self, x):
        ''' Forward pass through the network, returns the output logits '''
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc4(x)
        x = F.relu(x)
        return x

model = Network()
model
# Out:
# Network(
#   (fc1): Linear(in_features=6400, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=10000, bias=True)
#   (fc4): Linear(in_features=10000, out_features=2050, bias=True)
# )

# %%
del D
tensor_x = torch.stack([torch.Tensor(i) for i in outPutMidiArray]) # transform to torch tensors
del outPutMidiArray
tensor_y = torch.stack([torch.Tensor(i) for i in np.abs(D_data)])
del D_data
tensor_x = tensor_x.view(tensor_x.shape[0],-1)
print(tensor_x.shape,tensor_y.shape)
my_dataset = utils.TensorDataset(tensor_x,tensor_y) # create your datset

train_size = int(0.8 * len(my_dataset))
test_size = len(my_dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(my_dataset, [train_size, test_size])

my_dataloader = utils.DataLoader(train_dataset,batch_size=128,shuffle=False) # create your dataloader
my_validationloader = utils.DataLoader(test_dataset,batch_size=128,shuffle=False) # create your dataloader

print(len(my_dataloader),len(my_validationloader))

my_testloader = utils.DataLoader(my_dataset) # create your dataloader


# Optimizers require the parameters to optimize and a learning rate
optimizer = optim.SGD(model.parameters(), lr=0.01,momentum=0.9)

criterion = nn.MSELoss()
# or criterion = nn.MSELoss()
# Get our data
# Out:
# torch.Size([141145, 6400]) torch.Size([141145, 2050])
# 883 221

# %%
plt.plot(tensor_x.numpy()[:,127])
plt.show()

# %%
##Reset
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
Counter=0;
LossOverEpoch=[]
EvalLoss=[]
model.train()
model.to(device)
# Out:
# Network(
#   (fc1): Linear(in_features=6400, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=10000, bias=True)
#   (fc4): Linear(in_features=10000, out_features=2050, bias=True)
# )

# %%
epochs = 250
for i in range(epochs):
    running_loss = 0
    model.train()
    for data, labels in my_dataloader:
        data, labels = data.to(device), labels.to(device)
        optimizer.zero_grad()     
        logits = model(data)
        loss =criterion(logits,labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    model.eval();
    evalLossNum=0
    generateAudio('4Beats2Mel.mid','./generatedData-v2/'+str(Counter))
    for data, labels in my_validationloader:
        data, labels = data.to(device), labels.to(device)
        pred= model(data)
        loss = criterion(pred,labels)
        evalLossNum += loss.item()
    LossOverEpoch.append(running_loss/len(my_dataloader))
    EvalLoss.append(evalLossNum/len(my_validationloader))
    print(str(f"Training loss: {running_loss/len(my_dataloader)}" +"   "+ str(Counter))+"  "+str(evalLossNum/len(my_validationloader)))
    Counter+=1
# Out:
# generating audio and Spectrum image
# Training loss: 0.5361722554517899   84  0.557414142659347
# generating audio and Spectrum image
# Training loss: 0.5349436958878389   85  0.5532809042822722
# generating audio and Spectrum image
# Training loss: 0.5340004158992054   86  0.5525565620730905
# generating audio and Spectrum image
# Training loss: 0.5322887508677464   87  0.5526318190054657
# generating audio and Spectrum image
# Training loss: 0.5308839411792237   88  0.5523842523270602
# generating audio and Spectrum image
# Training loss: 0.5294132388259114   89  0.5491972743655762
# generating audio and Spectrum image
# Training loss: 0.5279452490239559   90  0.5499544549581692
# generating audio and Spectrum image
# Training loss: 0.5271329625614097   91  0.548605718494001
# generating audio and Spectrum image
# Training loss: 0.5259297673726541   92  0.5481210407628193
# generating audio and Spectrum image
# Training loss: 0.5253021991468907   93  0.5472177298090577
# generating audio and Spectrum image
# Training loss: 0.5246936570882528   94  0.5475518449938674
# generating audio and Spectrum image
# Training loss: 0.5231778075578933   95  0.547908250023337
# generating audio and Spectrum image
# Training loss: 0.5223754158713945   96  0.5449196956546059
# generating audio and Spectrum image
# Training loss: 0.5212754617663499   97  0.544840424848358
# generating audio and Spectrum image
# Training loss: 0.5205103178188998   98  0.5468564235786507
# generating audio and Spectrum image
# Training loss: 0.5195512353091386   99  0.54681418060717
# generating audio and Spectrum image
# Training loss: 0.5184953446296441   100  0.5468600844096274
# generating audio and Spectrum image
# Training loss: 0.5171184732514357   101  0.5471150438170628
# generating audio and Spectrum image
# Training loss: 0.5161124232941279   102  0.5437382481216845
# generating audio and Spectrum image
# Training loss: 0.5149747729976477   103  0.5440122334126434
# generating audio and Spectrum image
# Training loss: 0.5140296556941515   104  0.5443987725007587
# generating audio and Spectrum image
# Training loss: 0.5127497161838773   105  0.5429645949359393
# generating audio and Spectrum image
# Training loss: 0.5116692109799196   106  0.5393313606400295
# generating audio and Spectrum image
# Training loss: 0.5105709136544916   107  0.5399817797393281
# generating audio and Spectrum image
# Training loss: 0.5094762441121033   108  0.5435593323739945
# generating audio and Spectrum image
# Training loss: 0.5087165483869486   109  0.5411175672824566
# generating audio and Spectrum image
# Training loss: 0.5074248425620329   110  0.5426095706575057
# generating audio and Spectrum image
# Training loss: 0.5068683331307037   111  0.544425960714461
# generating audio and Spectrum image
# Training loss: 0.5057691999226978   112  0.5424546534659097
# generating audio and Spectrum image
# Training loss: 0.5048622656381548   113  0.5370498031242941
# generating audio and Spectrum image
# Training loss: 0.5038484439236931   114  0.5388306917378266
# generating audio and Spectrum image
# Training loss: 0.5029627007441775   115  0.5365070180116196
# generating audio and Spectrum image
# Training loss: 0.5020060787317032   116  0.5330013317220351
# generating audio and Spectrum image
# Training loss: 0.5010801924652043   117  0.5324455192186174
# generating audio and Spectrum image
# Training loss: 0.5006377012178825   118  0.5321443629750299
# generating audio and Spectrum image
# Training loss: 0.49948601831396194   119  0.5319693328568299
# generating audio and Spectrum image
# Training loss: 0.4988524285002716   120  0.531109675158203
# generating audio and Spectrum image
# Training loss: 0.49781671912321823   121  0.5287724845279935
# generating audio and Spectrum image
# Training loss: 0.4973154853046413   122  0.5290513033241169
# generating audio and Spectrum image
# Training loss: 0.49636310885743673   123  0.5271786173544318
# generating audio and Spectrum image
# Training loss: 0.4958389266430994   124  0.5271749836287347
# generating audio and Spectrum image
# Training loss: 0.4953535113774772   125  0.5266444332459393
# generating audio and Spectrum image
# Training loss: 0.49446812363200116   126  0.5244111917676969
# generating audio and Spectrum image
# Training loss: 0.49373674325197764   127  0.5243112966755397
# generating audio and Spectrum image
# Training loss: 0.49327526768903635   128  0.5235699861567484
# generating audio and Spectrum image
# Training loss: 0.49244487447619845   129  0.5228890092933879
# generating audio and Spectrum image
# Training loss: 0.4919129410254456   130  0.5229535032721127
# generating audio and Spectrum image
# Training loss: 0.49121568659963855   131  0.5214196884524229
# generating audio and Spectrum image
# Training loss: 0.4904080396127863   132  0.5212137347163118
# generating audio and Spectrum image
# Training loss: 0.4897267315895344   133  0.5208960182256828
# generating audio and Spectrum image
# Training loss: 0.48933063597668336   134  0.5198731388711282
# generating audio and Spectrum image
# Training loss: 0.4886988320410049   135  0.5187075279686786
# generating audio and Spectrum image
# Training loss: 0.48778144341902985   136  0.5184694701190448
# generating audio and Spectrum image
# Training loss: 0.48729986597025515   137  0.5172870097117187
# generating audio and Spectrum image
# Training loss: 0.4867744715135473   138  0.5160303594569815
# generating audio and Spectrum image
# Training loss: 0.4862079961923619   139  0.5154724656456736
# generating audio and Spectrum image
# Training loss: 0.48574644695051933   140  0.5151814559466159
# generating audio and Spectrum image
# Training loss: 0.4852024674888105   141  0.5147590521234193
# generating audio and Spectrum image
# Training loss: 0.48464607038152313   142  0.5144713898589708
# generating audio and Spectrum image
# Training loss: 0.48392705290260835   143  0.5141171444864834
# generating audio and Spectrum image
# Training loss: 0.48347536920826134   144  0.5139715617598452
# generating audio and Spectrum image
# Training loss: 0.4830088959342356   145  0.5141395628452301
# generating audio and Spectrum image
# Training loss: 0.4821608270078661   146  0.5127026098885687
# generating audio and Spectrum image
# Training loss: 0.48135155702636306   147  0.5124352537938373
# generating audio and Spectrum image
# Training loss: 0.48071314365785495   148  0.5117422104960653
# generating audio and Spectrum image
# Training loss: 0.4802469218641283   149  0.5119181100059959
# generating audio and Spectrum image
# Training loss: 0.47962043742361316   150  0.5114514873577998
# generating audio and Spectrum image
# Training loss: 0.47891580660237865   151  0.5118299273613891
# generating audio and Spectrum image
# Training loss: 0.47825157507359645   152  0.5112681274230664
# generating audio and Spectrum image
# Training loss: 0.47786055294330637   153  0.5105112863881556
# generating audio and Spectrum image
# Training loss: 0.47725447323827214   154  0.5097910473249617
# generating audio and Spectrum image
# Training loss: 0.4767739123085752   155  0.5104032037484699
# generating audio and Spectrum image
# Training loss: 0.4761452160834726   156  0.5100789721465219
# generating audio and Spectrum image
# Training loss: 0.47562123252878374   157  0.5100081830003143
# generating audio and Spectrum image
# Training loss: 0.47518211768545626   158  0.508884306676787
# generating audio and Spectrum image
# Training loss: 0.47478107387455243   159  0.5085830000730661
# generating audio and Spectrum image
# Training loss: 0.4744014699488777   160  0.5092646243615387
# generating audio and Spectrum image
# Training loss: 0.4738382623865272   161  0.508534299572129
# generating audio and Spectrum image
# Training loss: 0.47348664257156486   162  0.5090395232401282
# generating audio and Spectrum image
# Training loss: 0.47305540883932623   163  0.508583841415552
# generating audio and Spectrum image
# Training loss: 0.4725730725619963   164  0.5078548188932341
# generating audio and Spectrum image
# Training loss: 0.4720709939842721   165  0.5088030396543477
# generating audio and Spectrum image
# Training loss: 0.4716644405576138   166  0.5087508467527536
# generating audio and Spectrum image
# Training loss: 0.47120813495508   167  0.5080594072514529
# generating audio and Spectrum image
# Training loss: 0.47078939479177695   168  0.5092565169161801
# generating audio and Spectrum image
# Training loss: 0.47036176525047924   169  0.5098662938737222
# generating audio and Spectrum image
# Training loss: 0.4698835316695281   170  0.5105285202216239
# generating audio and Spectrum image
# Training loss: 0.4694728342181289   171  0.5097243953074805
# generating audio and Spectrum image
# Training loss: 0.46906789691774925   172  0.511439159714798
# generating audio and Spectrum image
# Training loss: 0.46877109619661206   173  0.5114614324332363
# generating audio and Spectrum image
# Training loss: 0.4684132986943557   174  0.5133498071005981
# generating audio and Spectrum image
# Training loss: 0.46806749888819177   175  0.5149830284431509
# generating audio and Spectrum image
# Training loss: 0.46762592734458897   176  0.5166330367191885
# generating audio and Spectrum image
# Training loss: 0.4675099886152239   177  0.5169508581247805
# generating audio and Spectrum image
# Training loss: 0.4671719285025602   178  0.5222523728916548
# generating audio and Spectrum image
# Training loss: 0.4666243199415142   179  0.5309412333760326
# generating audio and Spectrum image
# Training loss: 0.46655457477809886   180  0.5316299187921291
# generating audio and Spectrum image
# Training loss: 0.46619984264551984   181  0.5338227267448719
# generating audio and Spectrum image
# Training loss: 0.465900127253878   182  0.5338171423830058
# generating audio and Spectrum image
# Training loss: 0.4656007516188368   183  0.5300599123557769
# generating audio and Spectrum image
# Training loss: 0.4652664298413159   184  0.5318380560540505
# generating audio and Spectrum image
# Training loss: 0.4648121056375795   185  0.5327993474934436
# generating audio and Spectrum image
# Training loss: 0.4644040161087721   186  0.5327912187414472
# generating audio and Spectrum image
# Training loss: 0.46406081295229434   187  0.5329540222208964
# generating audio and Spectrum image
# Training loss: 0.4636396998254791   188  0.5320725555603321
# generating audio and Spectrum image
# Training loss: 0.4632584541732296   189  0.5294951745287865
# generating audio and Spectrum image
# Training loss: 0.46299775710934826   190  0.5314264511900251
# generating audio and Spectrum image
# Training loss: 0.46267269409998896   191  0.5284201678107766
# generating audio and Spectrum image
# Training loss: 0.4623105008564341   192  0.527749206011112
# generating audio and Spectrum image
# Training loss: 0.4620132531004611   193  0.5266895960359013
# generating audio and Spectrum image
# Training loss: 0.4615192338571138   194  0.526408576452894
# generating audio and Spectrum image
# Training loss: 0.4612739553436688   195  0.52317400944179
# generating audio and Spectrum image
# Training loss: 0.46100058267367655   196  0.5223157407201793
# generating audio and Spectrum image
# Training loss: 0.46073372555751085   197  0.5182142751249252
# generating audio and Spectrum image
# Training loss: 0.46031574228206823   198  0.5195038315936991
# generating audio and Spectrum image
# Training loss: 0.45997614375529716   199  0.5163548853062936
# generating audio and Spectrum image
# Training loss: 0.45954584418917294   200  0.5175095269313226
# generating audio and Spectrum image
# Training loss: 0.4590917567333306   201  0.5157286744581628
# generating audio and Spectrum image
# Training loss: 0.45866393332505684   202  0.5150935835967776
# generating audio and Spectrum image
# Training loss: 0.4581630584337703   203  0.5154828113668105
# generating audio and Spectrum image
# Training loss: 0.45788642905846594   204  0.5144589373428897
# generating audio and Spectrum image
# Training loss: 0.4574654299432532   205  0.5133713095436269
# generating audio and Spectrum image
# Training loss: 0.4570070322210629   206  0.5106055102736702
# generating audio and Spectrum image
# Training loss: 0.45659292712892036   207  0.5103528475329887
# generating audio and Spectrum image
# Training loss: 0.4561639079994956   208  0.5093730897115906
# generating audio and Spectrum image
# Training loss: 0.4558123961715439   209  0.5094580986111412
# generating audio and Spectrum image
# Training loss: 0.45537700747917087   210  0.5097984658107498
# generating audio and Spectrum image
# Training loss: 0.4550174718062443   211  0.5091800541359914
# generating audio and Spectrum image
# Training loss: 0.4546477868224864   212  0.5078865589059856
# generating audio and Spectrum image
# Training loss: 0.4542358408799123   213  0.5072058435209197
# generating audio and Spectrum image
# Training loss: 0.45386562153005117   214  0.5065284813691049
# generating audio and Spectrum image
# Training loss: 0.4535391484793288   215  0.506543290695993
# generating audio and Spectrum image
# Training loss: 0.4532776440188947   216  0.5054231050057648
# generating audio and Spectrum image
# Training loss: 0.4530262213668629   217  0.505291496197023
# generating audio and Spectrum image
# Training loss: 0.45270270183429306   218  0.504701549920561
# generating audio and Spectrum image
# Training loss: 0.4524788062340271   219  0.5042125778230606
# generating audio and Spectrum image
# Training loss: 0.4520380572750236   220  0.5041011736403763
# generating audio and Spectrum image
# Training loss: 0.4518935378822303   221  0.503703532715189
# generating audio and Spectrum image
# Training loss: 0.4515600322597024   222  0.5033171651589924
# generating audio and Spectrum image
# Training loss: 0.4511601612697506   223  0.5020765001417825
# generating audio and Spectrum image
# Training loss: 0.4511148092228316   224  0.5025033601538628
# generating audio and Spectrum image
# Training loss: 0.45080096435776384   225  0.5022478251975047
# generating audio and Spectrum image
# Training loss: 0.45040734453149994   226  0.5012026216109954
# generating audio and Spectrum image
# Training loss: 0.4500708787587059   227  0.5015684808541208
# generating audio and Spectrum image
# Training loss: 0.4498652533996146   228  0.501876578611486
# generating audio and Spectrum image
# Training loss: 0.4496652504697121   229  0.501939934168466
# generating audio and Spectrum image
# Training loss: 0.44938528824635565   230  0.5020067254882054
# generating audio and Spectrum image
# Training loss: 0.44901618482977457   231  0.5021125902147854
# generating audio and Spectrum image
# Training loss: 0.4488061055929177   232  0.5017670897337106
# generating audio and Spectrum image
# Training loss: 0.4485169215252283   233  0.501648400434002
# generating audio and Spectrum image
# Training loss: 0.448193446831147   234  0.5017511882393608
# generating audio and Spectrum image
# Training loss: 0.4480216271778735   235  0.5020356621947224
# generating audio and Spectrum image
# Training loss: 0.44761025397653353   236  0.5016362642810356
# generating audio and Spectrum image
# Training loss: 0.4473557168805586   237  0.5019767512293423
# generating audio and Spectrum image
# Training loss: 0.44709029906805886   238  0.5010356119585253
# generating audio and Spectrum image
# Training loss: 0.44679934289285306   239  0.5006470672145689
# generating audio and Spectrum image
# Training loss: 0.4465358609487624   240  0.5002067579942591
# generating audio and Spectrum image
# Training loss: 0.44611177722568013   241  0.49997766363135293
# generating audio and Spectrum image
# Training loss: 0.4459350553266324   242  0.4991747178642998
# generating audio and Spectrum image
# Training loss: 0.4456351762416004   243  0.49859212291726157
# generating audio and Spectrum image
# Training loss: 0.4453821938446937   244  0.49914500737621775
# generating audio and Spectrum image
# Training loss: 0.44521946369724125   245  0.4995069711456471
# generating audio and Spectrum image
# Training loss: 0.44500402913830694   246  0.4992892456270451
# generating audio and Spectrum image
# Training loss: 0.4448716217569695   247  0.4995748528797702
# generating audio and Spectrum image
# Training loss: 0.44470285449603136   248  0.4996075933605298
# generating audio and Spectrum image
# Training loss: 0.4445317450864399   249  0.5010687185628382
# generating audio and Spectrum image
# Training loss: 0.4444072091295927   250  0.5007925479929911
# generating audio and Spectrum image
# Training loss: 0.444300762574913   251  0.5016488892730006
# generating audio and Spectrum image
# Training loss: 0.44412429343871057   252  0.5007932272432077
# generating audio and Spectrum image
# Training loss: 0.44393493255361965   253  0.5014116998711323
# generating audio and Spectrum image
# Training loss: 0.4438204485184744   254  0.5022777558991273
# generating audio and Spectrum image
# Training loss: 0.44354376399368556   255  0.5021484028969415
# generating audio and Spectrum image
# Training loss: 0.4433202027498258   256  0.5030854557434358
# generating audio and Spectrum image
# Training loss: 0.44309633730626996   257  0.502509406654004
# generating audio and Spectrum image
# Training loss: 0.44270070199248207   258  0.5025391617781436
# generating audio and Spectrum image
# Training loss: 0.44242839481457985   259  0.5026276185771459
# generating audio and Spectrum image
# Training loss: 0.4421224508894394   260  0.5031643364224498
# generating audio and Spectrum image
# Training loss: 0.44173154452581503   261  0.5047424485510831
# generating audio and Spectrum image
# Training loss: 0.4413433711499077   262  0.5036533341418564
# generating audio and Spectrum image
# Training loss: 0.44080129743364904   263  0.5037661275712613
# generating audio and Spectrum image
# Training loss: 0.4403307948552604   264  0.5021296397053818
# generating audio and Spectrum image
# Training loss: 0.440071629691502   265  0.503388306404131
# generating audio and Spectrum image
# Training loss: 0.43962678564701857   266  0.5026230167479536
# generating audio and Spectrum image
# Training loss: 0.4391943034742319   267  0.5024023722199833
# generating audio and Spectrum image
# Training loss: 0.4390094399384707   268  0.5039101066362804
# generating audio and Spectrum image
# Training loss: 0.43860178053514065   269  0.504612421423062
# generating audio and Spectrum image
# Training loss: 0.438273054962115   270  0.5043591469930847
# generating audio and Spectrum image
# Training loss: 0.4379570430834458   271  0.5041177139293015
# generating audio and Spectrum image
# Training loss: 0.43768427974100427   272  0.5056911824245798
# generating audio and Spectrum image
# Training loss: 0.43733228095053006   273  0.5063130270302026
# generating audio and Spectrum image
# Training loss: 0.43705148022887663   274  0.5070839096787828
# generating audio and Spectrum image
# Training loss: 0.43674175620146544   275  0.5067648844481594
# generating audio and Spectrum image
# Training loss: 0.43637728957735666   276  0.5074761174113502
# generating audio and Spectrum image
# Training loss: 0.4361319254708317   277  0.5070814542910632
# generating audio and Spectrum image
# Training loss: 0.43586703085278333   278  0.5076178519973927
# generating audio and Spectrum image
# Training loss: 0.4355390403812091   279  0.5080088178766259
# generating audio and Spectrum image
# Training loss: 0.4353936352046673   280  0.5069001701352823
# generating audio and Spectrum image
# Training loss: 0.43501748321820494   281  0.5067971083103802
# generating audio and Spectrum image
# Training loss: 0.4347112371015657   282  0.5064647555081553
# generating audio and Spectrum image
# Training loss: 0.43438671789177413   283  0.5067373743424048
# generating audio and Spectrum image
# Training loss: 0.4340435127102235   284  0.5041248505741223
# generating audio and Spectrum image
# Training loss: 0.4336586518978884   285  0.5053705721419322
# generating audio and Spectrum image
# Training loss: 0.4332796197852894   286  0.5043829941102282
# generating audio and Spectrum image
# Training loss: 0.4331208501234735   287  0.5029327677925248
# generating audio and Spectrum image
# Training loss: 0.4327595203541143   288  0.5039015603820662
# generating audio and Spectrum image
# Training loss: 0.4325372077364344   289  0.5042515178611375
# generating audio and Spectrum image
# Training loss: 0.43234050459526946   290  0.5037866553030402
# generating audio and Spectrum image
# Training loss: 0.43201361284385587   291  0.5048252601699053
# generating audio and Spectrum image
# Training loss: 0.4318403171824707   292  0.504768382100498
# generating audio and Spectrum image
# Training loss: 0.43159696183010243   293  0.5051714497454026
# generating audio and Spectrum image
# Training loss: 0.43144680881959263   294  0.5047459505262418
# generating audio and Spectrum image
# Training loss: 0.43129096987698384   295  0.5050590840669779
# generating audio and Spectrum image
# Training loss: 0.43105722258409584   296  0.5054991939758283
# generating audio and Spectrum image
# Training loss: 0.4309406783916942   297  0.5062046184529007
# generating audio and Spectrum image
# Training loss: 0.4306037658034473   298  0.5054058808816504
# generating audio and Spectrum image
# Training loss: 0.4303439164181933   299  0.505203451506153
# generating audio and Spectrum image
# Training loss: 0.43010593235222694   300  0.5055418851958141
# generating audio and Spectrum image
# Training loss: 0.4299093988615416   301  0.5052551183495586
# generating audio and Spectrum image
# Training loss: 0.4297713007048059   302  0.5071601030244007
# generating audio and Spectrum image
# Training loss: 0.4295481106568031   303  0.5063241880673629
# generating audio and Spectrum image
# Training loss: 0.4292769413504703   304  0.5078020175387956
# generating audio and Spectrum image
# Training loss: 0.429013604317219   305  0.5080686512306265
# generating audio and Spectrum image
# Training loss: 0.42869924096599443   306  0.5094746331014245
# generating audio and Spectrum image
# Training loss: 0.42840290904922634   307  0.509979065591933
# generating audio and Spectrum image
# Training loss: 0.42815828713190784   308  0.5114946250732129
# generating audio and Spectrum image
# Training loss: 0.4278401689580721   309  0.5131122789501604
# generating audio and Spectrum image
# Training loss: 0.4276748039039318   310  0.513337500764234
# generating audio and Spectrum image
# Training loss: 0.4273980396250231   311  0.5143608405039861
# generating audio and Spectrum image
# Training loss: 0.427201424186389   312  0.5158020751508652
# generating audio and Spectrum image
# Training loss: 0.4269099000457459   313  0.5141502393586603
# generating audio and Spectrum image
# Training loss: 0.4265905828768913   314  0.5138449275116036
# generating audio and Spectrum image
# Training loss: 0.426449011348922   315  0.5140407642358029
# generating audio and Spectrum image
# Training loss: 0.42606687142449357   316  0.5140565353281358
# generating audio and Spectrum image
# Training loss: 0.42582688243513334   317  0.5138944520939529
# generating audio and Spectrum image
# Training loss: 0.4255894565467521   318  0.5146990313249475
# generating audio and Spectrum image
# Training loss: 0.42533883590795446   319  0.5138762560904835
# generating audio and Spectrum image
# Training loss: 0.42506729365070167   320  0.5149880782511439
# generating audio and Spectrum image
# Training loss: 0.42483580974800805   321  0.5148434083386244
# generating audio and Spectrum image
# Training loss: 0.4244952132653272   322  0.5164637798906991
# generating audio and Spectrum image
# Training loss: 0.42408610812872477   323  0.5161934875255256
# generating audio and Spectrum image
# Training loss: 0.42393535431284596   324  0.516989005367141
# generating audio and Spectrum image
# Training loss: 0.4237379272925084   325  0.5178996014379268
# generating audio and Spectrum image
# Training loss: 0.42353975281777495   326  0.5188180738175077
# generating audio and Spectrum image
# Training loss: 0.4232278176132982   327  0.5201722719280968
# generating audio and Spectrum image
# Training loss: 0.4229878037661685   328  0.520279038006364
# generating audio and Spectrum image
# Training loss: 0.42281875110496075   329  0.5211828980780295
# generating audio and Spectrum image
# Training loss: 0.42252383724546916   330  0.5227390146093671
# generating audio and Spectrum image
# Training loss: 0.42221053677061543   331  0.5229685684135057
# generating audio and Spectrum image
# Training loss: 0.42193703039518704   332  0.5248615879278916
# generating audio and Spectrum image
# Training loss: 0.42147981556868636   333  0.5263558027431436

# %%
plt.plot(LossOverEpoch)
plt.plot(EvalLoss)
plt.show()
torch.save(model.state_dict(), './w50-128*2-256-10000-2050-50Epochs.model')

# %%
model.eval()
outputArray=[]
for data, labels in my_testloader:
    with torch.no_grad():
        data, labels = data.to(device), labels.to(device)
        output = model.forward(data)
        outputArray.append(output[0].cpu().numpy())
outputArray=np.array(outputArray)

# %%
plt.imshow(outputArray.T)
plt.tight_layout()

# %%
transformedArray=[]
for elem in outputArray:
    a=np.array(np.int((n_fft/2+1)) *[1+1j])
    a.real=elem[:np.int(n_fft/2+1)]
    a.imag=elem[np.int(n_fft/2+1):]
    transformedArray.append(a)
transformedArray=np.array(transformedArray).T

# %%
print((transformedArray).shape)
Y_infered = librosa.istft(transformedArray,hop_length=hopLength)

# %%
ipd.Audio(Y_infered,rate=sr)

# %%
ipd.Audio(y,rate=sr)

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
librosa.display.specshow(librosa.amplitude_to_db(transformedArray.real,
                                                  ref=np.max),
                          y_axis='log', x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()

plt.subplot(1,3,2)
librosa.display.specshow(librosa.amplitude_to_db(D.real,
                                                  ref=np.max),
                          y_axis='log', x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()


plt.subplot(1,3,3)
librosa.display.specshow(librosa.amplitude_to_db(tensor_y.numpy()[:,:1025].T,
                                                  ref=np.max),
                          y_axis='log', x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()

# %%
output=np.array(0);
with torch.no_grad():
        test=torch.zeros([1, 128*windowSize], dtype=torch.float32)
       # test[0][46]=0.0;
        output = model.forward(test)
      #  test2=torch.ones([1, 1025], dtype=torch.float32)
      #  test2[0][46]=0.0;
        loss = criterion(output,torch.zeros([1, 1025], dtype=torch.float32))
        print(loss.item())
print(output.numpy()[0].shape,D_data[250].shape)
plt.plot(output.numpy()[0],'r')
#plt.plot(D_data[250],'g')
plt.show()

# %%
plt.imshow(outPutMidiArray[60].T)
plt.show()

# %%
midiTestArray=[]
HopSize=0.023
timeTracker=0.0
totalTimeTracker=0.0
MemoryArray=np.zeros(128)
lasttime=0;
bpm=60
for msg in mido.MidiFile('4Beats2Mel.mid'):
    if not msg.is_meta:
        totalTimeTracker+=msg.time
        nextEventTime=lasttime+msg.time
        while nextEventTime> timeTracker + HopSize:
            MemoryArray[127]=((timeTracker%4) * (bpm/60.0))/4.0
            midiTestArray.append(MemoryArray.copy())
            timeTracker += HopSize;
        if msg.type=='note_on':
            MemoryArray[msg.note]+=1.0;
        elif msg.type=='note_off':
            MemoryArray[msg.note]-=1.0;
        if(timeTracker+msg.time >= timeTracker + HopSize):
            MemoryArray[127]=((timeTracker%4) * (bpm/60.0))/4.0
            midiTestArray.append(MemoryArray.copy())
            timeTracker += HopSize
        lasttime += msg.time
    else:
        if(msg.type == 'set_tempo'):
            bpm=60000000/msg.tempo
midiTestArray = np.float32(np.array(midiTestArray))

MainMidiTest=[]
for i in range(midiTestArray.shape[0]):
    temp=[]
    for j in range(windowSize):
        val = int(j-(np.floor(windowSize/2)))
        val = i+val
        if(val<0 or val+1>midiTestArray.shape[0]):
             temp.append(np.zeros(midiTestArray.shape[1]))
        else:
            temp.append(midiTestArray[val])
    MainMidiTest.append(temp)
MainMidiTest=np.array(MainMidiTest)



tensor_x_test = torch.stack([torch.Tensor(i) for i in np.abs(MainMidiTest)])
tensor_x_test = tensor_x_test.view(tensor_x_test.shape[0],-1)

testDataSet = utils.TensorDataset(tensor_x_test,torch.zeros(tensor_x_test.shape)) # create your datset
TestLoader = utils.DataLoader(testDataSet) # create your dataloader


model.eval()
outputArray=[]
for data, labels in TestLoader:
    with torch.no_grad():
        data, labels = data.to(device), labels.to(device)
        output = model.forward(data)
        outputArray.append(output[0].cpu().numpy())
outputArray=np.array(outputArray).T
print((outputArray).shape)
Y_infered2 = librosa.istft(outputArray,hop_length=hopLength) 

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
librosa.display.specshow(librosa.amplitude_to_db(outputArray,
                                                  ref=np.max),
                          y_axis='log', x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()

plt.subplot(1,2,2)
plt.imshow(midiTestArray.T,interpolation='nearest', aspect='auto')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()

plt.show();


ipd.Audio(Y_infered2,rate=sr)

# %%
librosa.display.waveplot(y[:500], sr=sr);

# %%
def generateAudio(stringInput,fileName):
    print("generating audio and Spectrum image")
    midiTestArray=[]
    HopSize=0.023
    timeTracker=0.0
    totalTimeTracker=0.0
    MemoryArray=np.zeros(128)
    lasttime=0;
    bpm=60
    for msg in mido.MidiFile(stringInput):#'4Beats2Mel.mid'
        if not msg.is_meta:
            totalTimeTracker+=msg.time
            nextEventTime=lasttime+msg.time
            while nextEventTime> timeTracker + HopSize:
                MemoryArray[127]=((timeTracker%4) * (bpm/60.0))/4.0
                midiTestArray.append(MemoryArray.copy())
                timeTracker += HopSize;
            if msg.type=='note_on':
                MemoryArray[msg.note]+=1.0;
            elif msg.type=='note_off':
                MemoryArray[msg.note]-=1.0;
            if(timeTracker+msg.time >= timeTracker + HopSize):
                MemoryArray[127]=((timeTracker%4) * (bpm/60.0))/4.0
                midiTestArray.append(MemoryArray.copy())
                timeTracker += HopSize
            lasttime += msg.time
        else:
            if(msg.type == 'set_tempo'):
                bpm=60000000/msg.tempo
    midiTestArray = np.float32(np.array(midiTestArray))
    MainMidiTest=[]
    for i in range(midiTestArray.shape[0]):
        temp=[]
        for j in range(windowSize):
            val = int(j-(np.floor(windowSize/2)))
            val = i+val
            if(val<0 or val+1>midiTestArray.shape[0]):
                 temp.append(np.zeros(midiTestArray.shape[1]))
            else:
                temp.append(midiTestArray[val])
        MainMidiTest.append(temp)
    MainMidiTest=np.array(MainMidiTest)
    tensor_x_test = torch.stack([torch.Tensor(i) for i in np.abs(MainMidiTest)])
    tensor_x_test = tensor_x_test.view(tensor_x_test.shape[0],-1)
    testDataSet = utils.TensorDataset(tensor_x_test,torch.zeros(tensor_x_test.shape)) # create your datset
    TestLoader = utils.DataLoader(testDataSet) # create your dataloader
    model.eval()
    outputArray=[]
    for data, labels in TestLoader:
        with torch.no_grad():
            data, labels = data.to(device), labels.to(device)
            output = model.forward(data)
            outputArray.append(output[0].cpu().numpy())
    outputArray=np.array(outputArray)
    transformedArray=[]
    for elem in outputArray:
        a=np.array(np.int((n_fft/2+1)) *[1+1j])
        a.real=elem[:np.int(n_fft/2+1)]
        a.imag=elem[np.int(n_fft/2+1):]
        transformedArray.append(a)
    transformedArray=np.array(transformedArray).T
    Y_infered2 = librosa.istft(transformedArray,hop_length=hopLength) 
    plt.figure(figsize=(20,10))
    
    librosa.display.specshow(librosa.amplitude_to_db(transformedArray.real,
                                                      ref=np.max),
                              y_axis='log', x_axis='time')
    plt.title('Power spectrogram  ' + str(Counter) )
    plt.colorbar(format='%+2.0f dB')
    plt.tight_layout()


    #plt.show();
    plt.savefig(fileName+'.png')
    librosa.output.write_wav(fileName+'.wav', Y_infered2, sr)
    plt.close();

# %%
generateAudio('4Beats2Mel.mid','./generatedData/'+str(Counter))
# Out:
# generating audio and Spectrum image
